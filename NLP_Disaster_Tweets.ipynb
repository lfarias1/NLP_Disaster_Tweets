# %% [markdown]
# # Dataprep

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Data/Raw/train.csv')
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.shape
# Out:
# (7613, 5)

# %%
# Modelo básico inicial
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
X = tfidf.fit_transform(df['text'])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV, KFold
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression(penalty='elasticnet', solver='saga')
kf = KFold(n_splits=3)

# %%
params = {
    'C':[0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'l1_ratio':[0, 0.1, 0.25, 0.5, 0.75, 1],
}

# %%
rscv = RandomizedSearchCV(lr, params, n_iter=30, scoring='accuracy', cv=kf, return_train_score=True)

# %%
rscv.fit(X, df['target'])
# Out:
# C:\Users\lucas\AppData\Roaming\Python\Python36\site-packages\sklearn\linear_model\sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# RandomizedSearchCV(cv=KFold(n_splits=3, random_state=None, shuffle=False),
#                    error_score='raise-deprecating',
#                    estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                 dual=False, fit_intercept=True,
#                                                 intercept_scaling=1,
#                                                 l1_ratio=None, max_iter=100,
#                                                 multi_class='warn', n_jobs=None,
#                                                 penalty='elasticnet',
#                                                 random_state=None,
#                                                 solver='saga', tol=0.0001,
# ...

# %%
rscv.best_score_
# Out:
# 0.7441218967555497

# %%
rscv.best_estimator_
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=0.1, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='elasticnet',
#                    random_state=None, solver='saga', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
rscv.best_params_
# Out:
# {'l1_ratio': 0.1, 'C': 10}

# %%
test = pd.read_csv('Data/Raw/test.csv')

# %%
test
# Out:
#          id   keyword                          location  \
# 0         0       NaN                               NaN
# 1         2       NaN                               NaN
# 2         3       NaN                               NaN
# 3         9       NaN                               NaN
# 4        11       NaN                               NaN
# 5        12       NaN                               NaN
# 6        21       NaN                               NaN
# 7        22       NaN                               NaN
# 8        27       NaN                               NaN
# 9        29       NaN                               NaN
# 10       30       NaN                               NaN
# 11       35       NaN                               NaN
# 12       42       NaN                               NaN
# 13       43       NaN                               NaN
# 14       45       NaN                               NaN
# 15       46    ablaze                            London
# ...

# %%
X_test = tfidf.transform(test['text'])

# %%
y_pred = rscv.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
pd.read_csv('Data/Modeling/sample_submission.csv').head()
# Out:
#    id  target
# 0   0       0
# 1   2       0
# 2   3       0
# 3   9       0
# 4  11       0

# %%
pd.DataFrame({'id':test['id'], 'target':y_pred}).to_csv('Data/Modeling/Submission_v0.csv', sep=',', index=False)
